# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('bmh')
import seaborn as sns
import os

# %%
df= pd.read_csv(r'./HRDataset_v14.csv', sep=',')
print(df.shape)
df.head(2)
# Out:
# (311, 36)
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# ...

# %%
mean_df = df['Salary'].mean()
print("**punto 1**")
print("**promedio salarios**")
print(mean_df)
print(df.describe())
# Out:
# **punto 1**
# **promedio salarios**
# 69020.6848874598
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# ...

# %%
print("**punto 2**")
ax = sns.displot(data=df, x='Salary', fill=True)
ax.set(xlabel='Salario', ylabel='Cantidad', title='Distribución  de Salario')
plt.figure();
# Out:
# **punto 2**

# %%
print("**punto 3 Distribucion de salarios Departamento y Genero**")
ax = sns.catplot(data=df, kind='violin', x='Department', y='Salary', hue='Sex', split=True)
ax.set(xlabel='Departamento', ylabel='Rango Salarial', title='Distribucion de salarios Departamento y Genero');
# Out:
# **punto 3 Distribucion de salarios Departamento y Genero**

# %%
print("**punto 4 , Variantes**")
ax = sns.displot(data=df, x='DateofHire', fill=True)
ax.set(xlabel='Fecha de Contratacion', ylabel='Cantidad', title='Cantidad de contratados por fecha')
plt.figure();
# Out:
# **punto 4 , Variantes**

# %%
fecha = df['DateofHire']
fecha = pd.DatetimeIndex(fecha)
fecha
df['date'] = fecha
df['year'] = pd.DatetimeIndex(df['DateofHire']).year


df1 = df[['EmpID', 'year']]
df1.head()
df1=df1.groupby(['year'])
df1=df1.count().sort_values(['year'], ascending=False)

# %%
ax = sns.displot(data=df, x='Sex', fill=True)
ax.set(xlabel='Genero', ylabel='Cantidad', title='Cantidad de contratados por Genero')
plt.figure();

# %%
df1.head(10)
# Out:
#       EmpID
# year
# 2018      1
# 2017      6
# 2016     14
# 2015     36
# 2014     60
# 2013     44
# 2012     45
# 2011     83
# 2010      9
# 2009      7

# %%
import seaborn as sns
ax = sns.lineplot(data=df1, x="year", y="EmpID")
ax.set(xlabel='Año de contratacion', ylabel='Cantidad', title='Cantidad de contrataciones')
plt.figure();
